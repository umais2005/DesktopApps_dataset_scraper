# %%
import pandas as pd # type: ignore
import json
import re
import numpy as np
import warnings
from datetime import datetime

# %% [markdown]
# ### Import the data and make it workable

# %%
# append_paths = [f'../data/raw/by_pages/page_{page_num}_apps.json' for page_num in range(0,3000)]
# apps = []
# for page_path in append_paths:
#     page = json.loads(open(page_path, 'r').read())
#     apps.extend(page)
# with open('workable_apps.json','w')as f:
#     json.dump(apps, f, indent=4)

# %%
with open('workable_apps.json','r')as f:
    apps = json.loads(f.read())

# %%
df = pd.DataFrame([app for app in apps if app])
df.shape
# Out:
# (16463, 13)

# %%
n_na = df.isna().sum(axis=0)
n_na.round(2)  # Percentage of missing values
# Out:
# name                   0
# category               0
# developer           1064
# release              138
# setup_size             5
# setup_type             7
# compatibility        103
# operating_system     228
# ram_required         228
# hdd_space            228
# cpu                  228
# desc                   0
# features               0
# dtype: int64

# %%
df.head(2)
# Out:
#                              name    category         developer  \
# 0  EssentialPIM Pro Business 2024  Management  EssentialPIM Pro
# 1  Gillmeister Rename Expert 2024   Utilities       Gillmeister
#
#          release setup_size                                 setup_type  \
# 0  22th Jun 2024      32 MB  Offline Installer / Full Standalone Setup
# 1  22th Jun 2024      15 MB  Offline Installer / Full Standalone Setup
#
#                  compatibility operating_system ram_required hdd_space  \
# 0  32 Bit (x86) / 64 Bit (x64)   Windows 7/8/10         1 GB    200 MB
# 1  32 Bit (x86) / 64 Bit (x64)   Windows 7/8/10         1 GB    100 MB
#
#                                    cpu  \
# 0  Intel Dual Core or higher processor
# 1  Intel Dual Core or higher processor
#
#                                                 desc  \
# 0  EssentialPIM Pro Business 2024 is a profession...
# 1  Gillmeister Rename Expert 2024 is a profession...
#
#                                             features
# 0  Allows you to create a wide range of tasks, no...
# 1  Allows you to edit the names of files and fold...

# %% [markdown]
# ### We can clean the columns with units example: hdd_space, ram, setup size, and also cpu

# %% [markdown]
# #### These are some cleaning functions

# %%
def parse_memory(x: str):
   try:
      # Extract the number part from the string
      number = re.search(r'\d+(\.\d+)?', x).group()
      number = float(number)  # Convert the extracted number to a float
   except (AttributeError, ValueError, TypeError):
      return np.nan  # Return NaN if no valid number is found

   # Determine the unit and convert accordingly
   if re.search(r'(MB|mb)', x):
      return number
   elif re.search(r'(KB|kb)', x):
      return number / 1000
   elif re.search(r'(GB|gb)', x):
      return number * 1000
   return np.nan 

def parse_compatibility(x: str):
   try:
      matches =  re.findall(r'(32|64|86)', x)
   except TypeError:
      return np.nan
   if matches:
      if '86' in matches:
         matches.remove('86')
         matches.insert(0, '32')
      matches = list(set(matches))
      matches = [int(num) for num in matches]
      return min(matches)
   else:
      return np.nan
   
def parse_date(date):
    try:
        # Remove 'rd', 'th', 'st' from the day part
        cleaned_date_str = re.sub(r'(st|nd|rd|th)', '', date)

        # Parse the cleaned date string
        date_obj = datetime.strptime(cleaned_date_str, "%d %b %Y")
        return date_obj.strftime('%d-%m-%Y')
    except (ValueError, TypeError):
        return np.nan

# %%
newdf = df.copy()

# %%
newdf['setup_size_MB'] = newdf['setup_size'].map(parse_memory)

# %%
newdf['hdd_space_MB'] = newdf['hdd_space'].map(parse_memory)

# %%
newdf['ram_required_MB'] = newdf['ram_required'].map(parse_memory)

# %%
newdf['minimum_os_bits']  = newdf['compatibility'].map(parse_compatibility)

# %%
newdf['release'] = newdf['release'].map(parse_date)

# %%
newdf = newdf.drop('setup_type', axis=1)

# %%
newdf
# Out:
#                                                     name  \
# 0                         EssentialPIM Pro Business 2024
# 1                         Gillmeister Rename Expert 2024
# 2                       iToolab WatsG 2024 Free Download
# 3                                      ProPresenter 2024
# 4                                  DbVisualizer Pro 2024
# ...                                                  ...
# 16458           Windows 8.1 / Win 8 / Win 7 / Vista / XP
# 16459                      FL Studio 11 Producer Edition
# 16460                                       Fraps 3.5.99
# 16461  SolidWorks Premium Edition 2014 SP 1.0 (64/32 ...
# 16462    Adobe Illustrator CS6 16.0.0 ( 32 bit / 64 Bit)
#
#                     category         developer     release  \
# 0                 Management  EssentialPIM Pro  22-06-2024
# 1                  Utilities       Gillmeister  22-06-2024
# 2               File Sharing           iToolab  22-06-2024
# 3                 Multimedia      ProPresenter  22-06-2024
# 4      Database, Development  DbVisualizer Pro  22-06-2024
# ...                      ...               ...         ...
# 16458           Office Tools              None         NaN
# 16459                  Music              None         NaN
# 16460              Utilities              None         NaN
# 16461                 3D CAD              None         NaN
# 16462         Graphic Design              None         NaN
#
#                            setup_size                compatibility  \
# 0                               32 MB  32 Bit (x86) / 64 Bit (x64)
# 1                               15 MB  32 Bit (x86) / 64 Bit (x64)
# 2                               72 MB  32 Bit (x86) / 64 Bit (x64)
# 3                               80 MB  32 Bit (x86) / 64 Bit (x64)
# 4                              209 MB  32 Bit (x86) / 64 Bit (x64)
# ...                               ...                          ...
# 16458                          200 MB                         None
# 16459                          293 MB          ImageLine FL Studio
# 16460                          2.5 MB                 2nd Feb 2014
# 16461  7 GB (32 bit), 7.7 GB (64 bit)                   SolidWorks
# 16462                         1.84 GB            Adobe illustrator
#
#                                         operating_system  \
# 0                                         Windows 7/8/10
# 1                                         Windows 7/8/10
# 2                                 Windows 7/8/8.1/10/11.
# 3                                         Windows 7/8/10
# 4                                         Windows 7/8/10
# ...                                                  ...
# 16458                              Nitro PDF Pro 9.0.5.9
# 16459           Windows 8.1 / Win 8 / Win 7 / XP / Vista
# 16460                                                NaN
# 16461                Windows 8.1 / Win 8 / Win 7 / Vista
# 16462  Windows 8.1 / Windows 8 / Windows 7 / Windows ...
#
#                           ram_required                       hdd_space  \
# 0                                 1 GB                          200 MB
# 1                                 1 GB                          100 MB
# 2              512 MB of RAM required.  250 MB of free space required.
# 3                                 1 GB                          100 MB
# 4                                 2 GB                            1 GB
# ...                                ...                             ...
# 16458  55 MB ( 32 bit), 64 MB (64 bit)                    3rd Feb 2014
# 16459                             1 GB                            1 GB
# 16460                              NaN                             NaN
# 16461                             2 GB                          6.3 GB
# 16462                             1 GB                            2 GB
#
#                                         cpu  \
# 0       Intel Dual Core or higher processor
# 1       Intel Dual Core or higher processor
# 2      Intel Dual Core or higher processor.
# 3       Intel Dual Core or higher processor
# 4       Intel Dual Core or higher processor
# ...                                     ...
# 16458                              NitroPDF
# 16459                Intel Pentium IV 2 GHz
# 16460                                   NaN
# 16461                     Dual Core 1.6 Ghz
# 16462                      Intel Pentium IV
#
#                                                     desc  \
# 0      EssentialPIM Pro Business 2024 is a profession...
# 1      Gillmeister Rename Expert 2024 is a profession...
# 2      iToolab WatsG 2024 is a fantastic file sharing...
# 3      ProPresenter 2024 is a powerful application wh...
# 4      DbVisualizer Pro 2024 is a professional databa...
# ...                                                  ...
# 16458  Ever wondered how quality professional level P...
# 16459  Ever wondered which softwares are used for pro...
# 16460  Realtime video capturing in games was never so...
# 16461  There are a lot of enterprise level 3D CAD des...
# 16462  Its latest state of the art graphic Design Sof...
#
#                                                 features  setup_size_MB  \
# 0      Allows you to create a wide range of tasks, no...           32.0
# 1      Allows you to edit the names of files and fold...           15.0
# 2      Easily transfer WhatsApp data from Android and...           72.0
# 3      Allows you to view and watch live events in ex...           80.0
# 4      Allows database developers to create, edit, up...          209.0
# ...                                                  ...            ...
# 16458  PDF Creation Support. High End Security in Dig...          200.0
# 16459  Plugin Picker Multi-Track Audio Recording Mult...          293.0
# 16460  Operating Systems: Windows 8.1 / Windows 8 / W...            2.5
# 16461  Latest 3D CAD Designing techniques. Powerful S...         7000.0
# 16462  Latest Vector Graphics Drawing Tools Adobe Mer...         1840.0
#
#        hdd_space_MB  ram_required_MB  minimum_os_bits
# 0             200.0           1000.0             32.0
# 1             100.0           1000.0             32.0
# 2             250.0            512.0             32.0
# 3             100.0           1000.0             32.0
# 4            1000.0           2000.0             32.0
# ...             ...              ...              ...
# 16458           NaN             55.0              NaN
# 16459        1000.0           1000.0              NaN
# 16460           NaN              NaN              NaN
# 16461        6300.0           2000.0              NaN
# 16462        2000.0           1000.0              NaN
#
# [16463 rows x 16 columns]

# %%
newdf.dropna()
# Out:
#                                           name               category  \
# 0               EssentialPIM Pro Business 2024             Management
# 1               Gillmeister Rename Expert 2024              Utilities
# 2             iToolab WatsG 2024 Free Download           File Sharing
# 3                            ProPresenter 2024             Multimedia
# 4                        DbVisualizer Pro 2024  Database, Development
# ...                                        ...                    ...
# 16452                               CentOS 6.5      Operating Systems
# 16453                      Storm Codec 7.01.19             Multimedia
# 16454       Adobe InDesign CC 9.2 MultiLingual         Graphic Design
# 16455                       AVG PC TuneUp 2014          System Tuning
# 16456  Microsoft Dynamics CRM 2013 + All Tools            ERP Systems
#
#               developer     release setup_size                compatibility  \
# 0      EssentialPIM Pro  22-06-2024      32 MB  32 Bit (x86) / 64 Bit (x64)
# 1           Gillmeister  22-06-2024      15 MB  32 Bit (x86) / 64 Bit (x64)
# 2               iToolab  22-06-2024      72 MB  32 Bit (x86) / 64 Bit (x64)
# 3          ProPresenter  22-06-2024      80 MB  32 Bit (x86) / 64 Bit (x64)
# 4      DbVisualizer Pro  22-06-2024     209 MB  32 Bit (x86) / 64 Bit (x64)
# ...                 ...         ...        ...                          ...
# 16452       Open Source  07-03-2014     649 MB  32 Bit (x86) / 64 Bit (x64)
# 16453          Freeware  06-03-2014      24 MB  32 Bit (x86) / 64 Bit (x64)
# 16454    Adobe InDesign  05-03-2014    1.44 GB  32 Bit (x86) / 64 Bit (x64)
# 16455               AVG  02-03-2014   74.72 MB  32 Bit (x86) / 64 Bit (x64)
# 16456         Microsoft  06-03-2014     545 MB  32 Bit (x86) / 64 Bit (x64)
#
#                                    operating_system             ram_required  \
# 0                                    Windows 7/8/10                     1 GB
# 1                                    Windows 7/8/10                     1 GB
# 2                            Windows 7/8/8.1/10/11.  512 MB of RAM required.
# 3                                    Windows 7/8/10                     1 GB
# 4                                    Windows 7/8/10                     2 GB
# ...                                             ...                      ...
# 16452  HP-UX 11i with the latest codes and upgrades     1GB of RAM required.
# 16453              Windows XP/Vista/Windows 7 and 8    256MB of RAM required
# 16454                 Windows 2000/XP/Vista/7 and 8         2GB RAM Required
# 16455          Win 8.1 / Win 8 / Win 7 / Vista / XP                   512 MB
# 16456             Windows XP/Vista/ Windows 7 and 8     2GB of RAM required.
#
#                             hdd_space                                   cpu  \
# 0                              200 MB   Intel Dual Core or higher processor
# 1                              100 MB   Intel Dual Core or higher processor
# 2      250 MB of free space required.  Intel Dual Core or higher processor.
# 3                              100 MB   Intel Dual Core or higher processor
# 4                                1 GB   Intel Dual Core or higher processor
# ...                               ...                                   ...
# 16452             2GB space required.                           Pentium III
# 16453          100MB of space needed.                           Pentium III
# 16454              2GB space required                            Intel P-IV
# 16455                          100 MB                      Intel Pentium IV
# 16456          10GB of space required                      Dual Core 1.5GHz
#
#                                                     desc  \
# 0      EssentialPIM Pro Business 2024 is a profession...
# 1      Gillmeister Rename Expert 2024 is a profession...
# 2      iToolab WatsG 2024 is a fantastic file sharing...
# 3      ProPresenter 2024 is a powerful application wh...
# 4      DbVisualizer Pro 2024 is a professional databa...
# ...                                                  ...
# 16452  CentOS is a Linux based open source program fr...
# 16453  While watching movies and other videos on your...
# 16454  With Adobe InDesign, interactive documents can...
# 16455  Well there are couple of other software alread...
# 16456  Microsoft Dynamics CRM is the tool which is su...
#
#                                                 features  setup_size_MB  \
# 0      Allows you to create a wide range of tasks, no...          32.00
# 1      Allows you to edit the names of files and fold...          15.00
# 2      Easily transfer WhatsApp data from Android and...          72.00
# 3      Allows you to view and watch live events in ex...          80.00
# 4      Allows database developers to create, edit, up...         209.00
# ...                                                  ...            ...
# 16452  Open source. Reliable. Simple installation. Ea...         649.00
# 16453  Contains loads of codecs. Easy to use. Quick i...          24.00
# 16454  E Books, Brochures can be made easily. Easy to...        1440.00
# 16455  Cleaning of Junk Files. Boost Speed like a Fre...          74.72
# 16456  Builds customer relationship. Easy to use tool...         545.00
#
#        hdd_space_MB  ram_required_MB  minimum_os_bits
# 0             200.0           1000.0             32.0
# 1             100.0           1000.0             32.0
# 2             250.0            512.0             32.0
# 3             100.0           1000.0             32.0
# 4            1000.0           2000.0             32.0
# ...             ...              ...              ...
# 16452        2000.0           1000.0             32.0
# 16453         100.0            256.0             32.0
# 16454        2000.0           2000.0             32.0
# 16455         100.0            512.0             32.0
# 16456       10000.0           2000.0             32.0
#
# [13643 rows x 16 columns]
