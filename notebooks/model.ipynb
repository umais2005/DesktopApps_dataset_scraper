# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import nltk
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
def count_tokens(string):
    x = nltk.word_tokenize(string)
    x = len(x)
    return x

# %% [markdown]
# ### Lets make a basic model first

# %%
df = pd.read_csv("nlp_df.csv")

# %%
df = df.iloc[:,2:]

# %%
df.columns
# Out:
# Index(['name', 'developer', 'category', 'desc', 'features', 'img_link',
#        'tags'],
#       dtype='object')

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8915 entries, 0 to 8938
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       8915 non-null   object
#  1   developer  8915 non-null   object
#  2   category   8915 non-null   object
#  3   desc       8915 non-null   object
#  4   features   8915 non-null   object
#  5   img_link   8915 non-null   object
#  6   tags       8915 non-null   object
# dtypes: object(7)
# memory usage: 557.2+ KB

# %%
df['tags'].map(count_tokens)
# Out:
# 0       517
# 1       476
# 2       639
# 3       626
# 4       517
#        ...
# 8934    203
# 8935    297
# 8936    209
# 8937    271
# 8938    299
# Name: tags, Length: 8915, dtype: int64

# %%
import matplotlib.pyplot as plt

# Define the number of rows and columns for the subplot grid
num_cols = len(df.columns)
num_rows = (num_cols + 3) // 4  # Calculate number of rows needed

# Create subplots with 'num_rows' rows and 4 columns
fig, axes = plt.subplots(num_rows, 4, figsize=(16, 3 * num_rows))

# Flatten the axes array for easy iteration if num_rows > 1
axes = axes.flatten()

# Iterate over each column and subplot
for i, (colname, ax) in enumerate(zip(df.columns, axes)):
    # Plot histogram of the length of strings in the column
    df[colname].map(count_tokens).plot.hist(ax=ax, bins=20, edgecolor='black')
    
    # Set the title and labels
    ax.set_title(colname)
    ax.set_xlabel('String Length')
    ax.set_ylabel('Frequency')

# Hide any unused subplots
for j in range(i + 1, len(axes)):
    axes[j].axis('off')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Train Data should be like
#
# Text,label
#
# I will be using the features column as text because i think it is more representative of the category of the app. It is more concise whereas desc is an overview

# %%
X =
